# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    i  w        j1        j2  factor_e  exact_e_0  factor_c   calc_e_0  \
# 0  0  0  0.000000  1.000000  0.285714 -22.841434  0.286259 -22.749974
# 1  1  1  0.017452  0.999848  0.285719 -22.888452  0.286440 -22.730315
# 2  2  2  0.034899  0.999391  0.285735 -22.929781  0.285986 -22.835145
# 3  3  3  0.052336  0.998630  0.285761 -22.965408  0.286213 -22.765139
# 4  4  4  0.069756  0.997564  0.285797 -22.995321  0.285850 -22.914119
#
#         rad    r_j2_j1
# 0  0.000000        inf
# 1  0.005556  57.289962
# 2  0.011111  28.636253
# 3  0.016667  19.081137
# 4  0.022222  14.300666

# %%
df = pd.read_csv("data/j1j2_l_20/df_100_.csv")
df['r_j2_j1'] = round(df['j2']/df['j1'],6)

# %% [markdown]
# ### L = 20; iterations = 100

# %%
ax = df.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.axvline(x=55, color='r', label='axvline - full height')
plt.axvline(x=58, color='r', label='axvline - full height')
plt.axvline(x=179, color='r', label='axvline - full height')
plt.axvline(x=182, color='r', label='axvline - full height')
plt.axvline(x=286, color='r', label='axvline - full height')
plt.axvline(x=288, color='r', label='axvline - full height')

plt.show()

# %%
ax = df.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.axvline(x=55, color='r', label='axvline - full height')
plt.axvline(x=58, color='r', label='axvline - full height')
plt.axvline(x=179, color='r', label='axvline - full height')
plt.axvline(x=182, color='r', label='axvline - full height')
plt.axvline(x=286, color='r', label='axvline - full height')
plt.axvline(x=288, color='r', label='axvline - full height')

# %%
df.query("w == 56")[['w','rad','r_j2_j1']]
# Out:
#      w       rad   r_j2_j1
# 56  56  0.311111  0.674509

# %%
df.query("w == 57")[['w','rad','r_j2_j1']]
# Out:
#      w       rad   r_j2_j1
# 57  57  0.316667  0.649408

# %%
df.query("w == 181")[['w','rad','r_j2_j1']]
# Out:
#        w       rad    r_j2_j1
# 181  181  1.005556  57.289962

# %%
df.query("w == 286")[['w','rad','r_j2_j1']]
# Out:
#        w       rad   r_j2_j1
# 286  286  1.588889 -0.286745

# %%
ax = df.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.axvline(x=55, color='r', label='axvline - full height')
plt.axvline(x=58, color='r', label='axvline - full height')
plt.axvline(x=179, color='r', label='axvline - full height')
plt.axvline(x=182, color='r', label='axvline - full height')
plt.axvline(x=286, color='r', label='axvline - full height')
plt.axvline(x=288, color='r', label='axvline - full height')

plt.show()

# %%
df = pd.read_csv("data/j1j2_l_20/df_100_.csv")
ax = df.plot(x='rad', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.show()

# %%
df = pd.read_csv("data/j1j2_l_20/df_100_.csv")
ax = df.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta)")
ax.set_ylabel("(e_0)")
plt.show()

# %%
df.head()

# %% [markdown]
# ### L = 20; iterations = 600

# %%
df = pd.read_csv("data/j1j2_l_20/df_600_.csv")
ax = df.plot(x='rad', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.show()

# %%
df = pd.read_csv("data/j1j2_l_20/df_1200_.csv")
ax = df.plot(x='rad', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.show()
