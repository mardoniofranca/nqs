# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### L = 6; iterations = 600; alpha = 2

# %%
df_l_6_rbm_a_1 = pd.read_csv("data/result/6_600_A_2_RBM.csv")

# %%
df_l_6_rbm_a_1.head(20)
# Out:
#      i   w       rad        j1        j2  factor_e  exact_e_0  factor_c  \
# 0    0   0  0.000000  0.000000  1.000000  0.666667  -6.000000       599
# 1    1   1  0.017453  0.017452  0.999848  0.666667  -6.103801       599
# 2    2   2  0.034907  0.034899  0.999391  0.666667  -6.205742       599
# 3    3   3  0.052360  0.052336  0.998630  0.666667  -6.305793       599
# 4    4   4  0.069813  0.069756  0.997564  0.666667  -6.403923       599
# 5    5   5  0.087266  0.087156  0.996195  0.666667  -6.500103       599
# 6    6   6  0.104720  0.104528  0.994522  0.666667  -6.594302       599
# 7    7   7  0.122173  0.121869  0.992546  0.666667  -6.686493       599
# 8    8   8  0.139626  0.139173  0.990268  0.666667  -6.776647       599
# 9    9   9  0.157080  0.156434  0.987688  0.666667  -6.864737       599
# 10  10  10  0.174533  0.173648  0.984808  0.666667  -6.950736       599
# 11  11  11  0.191986  0.190809  0.981627  0.666667  -7.034617       599
# 12  12  12  0.209440  0.207912  0.978148  0.666667  -7.116356       599
# 13  13  13  0.226893  0.224951  0.974370  0.666667  -7.195927       599
# 14  14  14  0.244346  0.241922  0.970296  0.666667  -7.273306       599
# 15  15  15  0.261799  0.258819  0.965926  0.666667  -7.348469       599
# 16  16  16  0.279253  0.275637  0.961262  0.666667  -7.421394       599
# 17  17  17  0.296706  0.292372  0.956305  0.666667  -7.492059       599
# 18  18  18  0.314159  0.309017  0.951057  0.666667  -7.560441       599
# 19  19  19  0.331613  0.325568  0.945519  0.666667  -7.626520       599
#
#     calc_e_0
# 0  -1.999036
# 1  -1.962724
# 2  -2.089424
# 3  -1.892830
# 4  -2.133089
# 5  -2.235569
# 6  -2.281374
# 7  -2.227095
# 8  -2.535016
# 9  -2.813403
# 10 -2.875864
# 11 -2.744398
# 12 -3.238131
# 13 -2.450223
# 14 -2.941234
# 15 -3.001325
# 16 -3.439189
# 17 -3.480281
# 18 -3.901459
# 19 -3.658292

# %%
df_l_6_rbm_a_1.tail()
# Out:
#        i    w       rad        j1        j2  factor_e  exact_e_0  factor_c  \
# 355  355  355  6.195919 -0.087156  0.996195  0.668580  -6.160822       599
# 356  356  356  6.213372 -0.069756  0.997564  0.667930  -6.130973       599
# 357  357  357  6.230825 -0.052336  0.998630  0.667401  -6.099923       599
# 358  358  358  6.248279 -0.034899  0.999391  0.667004  -6.067714       599
# 359  359  359  6.265732 -0.017452  0.999848  0.666754  -6.034390       599
#
#      calc_e_0
# 355 -2.163421
# 356 -2.133939
# 357 -2.100858
# 358 -2.067897
# 359 -1.964440

# %%
ax = df_l_6_rbm_a_1.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.axvline(x=58, color='r', label='axvline - full height')
plt.axvline(x=60, color='r', label='axvline - full height')
plt.axvline(x=179, color='r', label='axvline - full height')
plt.axvline(x=182, color='r', label='axvline - full height')
plt.axvline(x=286, color='r', label='axvline - full height')
plt.axvline(x=288, color='r', label='axvline - full height')
plt.rcParams['figure.figsize'] = [8, 4]

plt.show()

# %% [markdown]
# ### L = 14; iterations = 600; alpha = 1

# %%
df = pd.read_csv("data/result/14_600_RBM.csv")

# %%
df.head()
# Out:
#    i  w       rad        j1        j2  factor_e  exact_e_0  factor_c  \
# 0  0  0  0.000000  0.000000  1.000000  0.285714 -22.841434       599
# 1  1  1  0.017453  0.017452  0.999848  0.285719 -22.888452       599
# 2  2  2  0.034907  0.034899  0.999391  0.285735 -22.929781       599
# 3  3  3  0.052360  0.052336  0.998630  0.285761 -22.965408       599
# 4  4  4  0.069813  0.069756  0.997564  0.285797 -22.995321       599
#
#     calc_e_0
# 0  -9.996905
# 1  -9.959122
# 2 -10.060346
# 3  -9.883483
# 4 -10.116116

# %%
ax = df.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.axvline(x=58, color='r', label='axvline - full height')
plt.axvline(x=60, color='r', label='axvline - full height')
plt.axvline(x=179, color='r', label='axvline - full height')
plt.axvline(x=182, color='r', label='axvline - full height')
plt.axvline(x=286, color='r', label='axvline - full height')
plt.axvline(x=288, color='r', label='axvline - full height')
plt.rcParams['figure.figsize'] = [8, 4]

plt.show()

# %%
### L = 14; iterations = 600; REDE = FFNN

# %%
df2 = pd.read_csv("data/result/14_600_FFNN.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0  i  w       rad        j1        j2  factor_e  exact_e_0  \
# 0           0  0  0  0.000000  0.000000  1.000000  0.285714 -22.841434
# 1           0  1  1  0.017453  0.017452  0.999848  0.285719 -22.888452
# 2           0  2  2  0.034907  0.034899  0.999391  0.285735 -22.929781
# 3           0  3  3  0.052360  0.052336  0.998630  0.285761 -22.965408
# 4           0  4  4  0.069813  0.069756  0.997564  0.285797 -22.995321
#
#    factor_c   calc_e_0
# 0  0.285714 -22.837659
# 1  0.285714 -22.849594
# 2  0.285714 -22.895293
# 3  0.285714 -22.962948
# 4  0.285714 -22.934473

# %%
ax = df2.plot(x='w', y=["exact_e_0", "calc_e_0"],marker='.' )
ax.set_xlabel("(theta/pi)")
ax.set_ylabel("(e_0)")
plt.axvline(x=58, color='r', label='axvline - full height')
plt.axvline(x=60, color='r', label='axvline - full height')
plt.axvline(x=179, color='r', label='axvline - full height')
plt.axvline(x=182, color='r', label='axvline - full height')
plt.axvline(x=286, color='r', label='axvline - full height')
plt.axvline(x=288, color='r', label='axvline - full height')
plt.rcParams['figure.figsize'] = [8, 4]

plt.show()
